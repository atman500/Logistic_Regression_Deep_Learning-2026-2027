# %% [markdown]
# <a href="https://colab.research.google.com/github/atman500/Logistic_Regression_Deep_Learning-2026-2027/blob/main/Multiple8lgistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-c7fb8b24-bdfb-407c-b3a7-47ffff363b3f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7fb8b24-bdfb-407c-b3a7-47ffff363b3f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('Multiple_logistic_Regression.csv',sep=';')
print(df.head())
# Out:
#    Study_Hours  Attendance_Percent  Assignments_Completed  Previous_Score  \
# 0         9.87                70.7                   10.0            66.7
# 1        11.63                76.7                    9.5            64.4
# 2         7.49                89.9                    8.9            57.8
# 3         1.17                76.8                    7.3            60.4
# 4         3.61                82.0                    6.4            71.2
#
#    Sleep_Hours  Pass
# 0          7.1     1
# 1          6.2     1
# 2          7.1     1
# 3          5.1     0
# 4          6.3     1

# %%
df=pd.read_csv('Multiple_logistic_Regression.csv',sep=';')
print(df.head())
# Out:
#    Study_Hours  Attendance_Percent  Assignments_Completed  Previous_Score  \
# 0         9.87                70.7                   10.0            66.7
# 1        11.63                76.7                    9.5            64.4
# 2         7.49                89.9                    8.9            57.8
# 3         1.17                76.8                    7.3            60.4
# 4         3.61                82.0                    6.4            71.2
#
#    Sleep_Hours  Pass
# 0          7.1     1
# 1          6.2     1
# 2          7.1     1
# 3          5.1     0
# 4          6.3     1

# %%
x=df[['Study_Hours','Attendance_Percent','Assignments_Completed','Previous_Score','Sleep_Hours']]

y=df['Pass']
print(x.head())
print(y.head())
# Out:
#    Study_Hours  Attendance_Percent  Assignments_Completed  Previous_Score  \
# 0         9.87                70.7                   10.0            66.7
# 1        11.63                76.7                    9.5            64.4
# 2         7.49                89.9                    8.9            57.8
# 3         1.17                76.8                    7.3            60.4
# 4         3.61                82.0                    6.4            71.2
#
#    Sleep_Hours
# 0          7.1
# 1          6.2
# 2          7.1
# 3          5.1
# 4          6.3
# 0    1
# 1    1
# 2    1
# 3    0
# 4    1
# Name: Pass, dtype: int64

# %%
print(df.describe())
# Out:
#        Study_Hours  Attendance_Percent  Assignments_Completed  Previous_Score  \
# count  1000.000000         1000.000000            1000.000000     1000.000000
# mean      6.381010           81.743900               7.440500       67.843300
# std       3.207491            9.961109               1.634038       11.854696
# min       1.000000           50.000000               2.800000       33.200000
# 25%       3.450000           74.975000               6.200000       60.200000
# 50%       6.350000           82.200000               7.600000       68.500000
# 75%       9.132500           89.000000               8.700000       75.900000
# max      11.980000          100.000000              10.000000      100.000000
#
#        Sleep_Hours         Pass
# count  1000.000000  1000.000000
# mean      6.950500     0.949000
# std       1.188365     0.220108
# min       4.000000     0.000000
# 25%       6.200000     1.000000
# 50%       6.900000     1.000000
# 75%       7.800000     1.000000
# ...

# %%
import sklearn.metrics as metrics
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
from sklearn.metrics import confusion_matrix

# %%
logistoc_model=sm.Logit(y,x).fit()
x=sm.add_constant(x)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.146480
#          Iterations 9

# %%
print(logistoc_model.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                   Pass   No. Observations:                 1000
# Model:                          Logit   Df Residuals:                      994
# Method:                           MLE   Df Model:                            5
# Date:                Sat, 12 Sep 2026   Pseudo R-squ.:                  0.2729
# Time:                        06:28:48   Log-Likelihood:                -146.48
# converged:                       True   LL-Null:                       -201.45
# Covariance Type:            nonrobust   LLR p-value:                 4.222e-22
# ...
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                   -12.6900      2.158     -5.881      0.000     -16.919      -8.461
# Study_Hours               0.4496      0.075      6.018      0.000       0.303       0.596
# ...

# %%
y_pred= logistoc_model.predict(x)
print(pd.DataFrame({
    "y_actual": y,
    "t_pred":y_pred
}))
# Out:
#      y_actual    t_pred
# 0           1  0.998719
# 1           1  0.998935
# 2           1  0.996241
# 3           0  0.563229
# 4           1  0.907829
# ..        ...       ...
# 995         1  0.802445
# 996         1  0.994616
# 997         1  0.987154
# 998         1  0.997425
# 999         1  0.959825
#
# [1000 rows x 2 columns]

# %%
y_pred_binary = (y_pred > 0.5).astype(int)
cofussion=confusion_matrix(y, y_pred_binary)
print(cofussion)
# Out:
# [[  4  47]
#  [  3 946]]

# %%
print(metrics.accuracy_score(y,y_pred_binary))
print(metrics.precision_score(y,y_pred_binary))
print(metrics.recall_score(y,y_pred_binary))
print(metrics.f1_score(y,y_pred_binary))
# Out:
# 0.95
# 0.9526686807653575
# 0.9968387776606955
# 0.9742533470648815
